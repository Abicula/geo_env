# %% [markdown]
# # Imports

# %%
## Importing needed packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pdb
import xarray as xr
import csv

# %% [markdown]
# # Accessing the file and plotting hydrographs

# %%
file_path = 'D:/CWatM/Tutorials/11_SensitivityAnalysis/run_100rain/discharge_daily.tss'

# Define lists to store timestamps and values
timestamps_100r = []
discharge1_100r = []  
discharge2_100r = [] 

# Open the file and read its contents
with open(file_path, 'r') as file:
    # Skip first lines until we reach the data
    for line in file:
        if line.strip().isdigit():
            break
    
    # Process the remaining lines containing data
    for line in file:
        # Split the line by whitespace
        parts = line.split()
        if len(parts) == 3:  # Assuming timestamp and two values
            timestamp = int(parts[0])
            value1 = float(parts[1])
            value2 = float(parts[2])
            
            # Append data to lists
            timestamps_100r.append(timestamp)
            discharge1_100r.append(value1)
            discharge2_100r.append(value2)

# # # Print the extracted data
# for i in range(len(timestamps)):
#     print(f"Timestamp: {timestamps[i]}, Value1: {discharge1[i]}, Value2: {discharge2[i]}")

# %%
file_path = 'D:/CWatM/Tutorials/11_SensitivityAnalysis/run_85rain/discharge_daily.tss'

# Define lists to store timestamps and values
timestamps_85r = []
discharge1_85r = []  
discharge2_85r = [] 

# Open the file and read its contents
with open(file_path, 'r') as file:
    # Skip first lines until we reach the data
    for line in file:
        if line.strip().isdigit():
            break
    
    # Process the remaining lines containing data
    for line in file:
        # Split the line by whitespace
        parts = line.split()
        if len(parts) == 3:  # Assuming timestamp and two values
            timestamp = int(parts[0])
            value1 = float(parts[1])
            value2 = float(parts[2])
            
            # Append data to lists
            timestamps_85r.append(timestamp)
            discharge1_85r.append(value1)
            discharge2_85r.append(value2)

# # # Print the extracted data
# for i in range(len(timestamps)):
#     print(f"Timestamp: {timestamps[i]}, Value1: {discharge1[i]}, Value2: {discharge2[i]}")

# %%
file_path = 'D:/CWatM/Tutorials/11_SensitivityAnalysis/run_60rain/discharge_daily.tss'

# Define lists to store timestamps and values
timestamps_60r = []
discharge1_60r = []  
discharge2_60r = [] 

# Open the file and read its contents
with open(file_path, 'r') as file:
    # Skip first lines until we reach the data
    for line in file:
        if line.strip().isdigit():
            break
    
    # Process the remaining lines containing data
    for line in file:
        # Split the line by whitespace
        parts = line.split()
        if len(parts) == 3:  # Assuming timestamp and two values
            timestamp = int(parts[0])
            value1 = float(parts[1])
            value2 = float(parts[2])
            
            # Append data to lists
            timestamps_60r.append(timestamp)
            discharge1_60r.append(value1)
            discharge2_60r.append(value2)

# # # Print the extracted data
# for i in range(len(timestamps)):
#     print(f"Timestamp: {timestamps[i]}, Value1: {discharge1[i]}, Value2: {discharge2[i]}")

# %%
file_path = 'D:/CWatM/Tutorials/11_SensitivityAnalysis/run_116temp/discharge_daily.tss'

# Define lists to store timestamps and values
timestamps_116t = []
discharge1_116t = []  
discharge2_116t = [] 

# Open the file and read its contents
with open(file_path, 'r') as file:
    # Skip first lines until we reach the data
    for line in file:
        if line.strip().isdigit():
            break
    
    # Process the remaining lines containing data
    for line in file:
        # Split the line by whitespace
        parts = line.split()
        if len(parts) == 3:  # Assuming timestamp and two values
            timestamp = int(parts[0])
            value1 = float(parts[1])
            value2 = float(parts[2])
            
            # Append data to lists
            timestamps_116t.append(timestamp)
            discharge1_116t.append(value1)
            discharge2_116t.append(value2)

# # # Print the extracted data
# for i in range(len(timestamps)):
#     print(f"Timestamp: {timestamps[i]}, Value1: {discharge1[i]}, Value2: {discharge2[i]}")

# %%
file_path = 'D:/CWatM/Tutorials/11_SensitivityAnalysis/run_140temp/discharge_daily.tss'

# Define lists to store timestamps and values
timestamps_140t = []
discharge1_140t = []  
discharge2_140t = [] 

# Open the file and read its contents
with open(file_path, 'r') as file:
    # Skip first lines until we reach the data
    for line in file:
        if line.strip().isdigit():
            break
    
    # Process the remaining lines containing data
    for line in file:
        # Split the line by whitespace
        parts = line.split()
        if len(parts) == 3:  # Assuming timestamp and two values
            timestamp = int(parts[0])
            value1 = float(parts[1])
            value2 = float(parts[2])
            
            # Append data to lists
            timestamps_140t.append(timestamp)
            discharge1_140t.append(value1)
            discharge2_140t.append(value2)

# # # Print the extracted data
# for i in range(len(timestamps)):
#     print(f"Timestamp: {timestamps[i]}, Value1: {discharge1[i]}, Value2: {discharge2[i]}")

# %%
# Normalize timestamp to start from 0
## 0 means 1/1/2000

first_timestamp = timestamps_100r[0]

for i in range(len(timestamps_100r)):
    timestamps_100r[i] = timestamps_100r[i] - first_timestamp

# %%
# Normalize timestamp to start from 0
## 0 means 1/1/2000

first_timestamp = timestamps_85r[0]

for i in range(len(timestamps_85r)):
    timestamps_85r[i] = timestamps_85r[i] - first_timestamp

# %%
# Normalize timestamp to start from 0
## 0 means 1/1/2000

first_timestamp = timestamps_60r[0]

for i in range(len(timestamps_60r)):
    timestamps_60r[i] = timestamps_60r[i] - first_timestamp

# %%
# Normalize timestamp to start from 0
## 0 means 1/1/2000

first_timestamp = timestamps_116t[0]

for i in range(len(timestamps_116t)):
    timestamps_116t[i] = timestamps_116t[i] - first_timestamp

# %%
# Normalize timestamp to start from 0
## 0 means 1/1/2000

first_timestamp = timestamps_140t[0]

for i in range(len(timestamps_140t)):
    timestamps_140t[i] = timestamps_140t[i] - first_timestamp

# %%
# Plotting

plt.plot(timestamps_100r, discharge1_85r, label='Less rain by 15%', color='#A95681')
plt.plot(timestamps_100r, discharge1_100r, label='unmodified rain', color='#5681A9')
plt.plot(timestamps_100r, discharge1_60r, label='Less rain by 40%', color='#81A956')
plt.title('Discharge in Rhine basin')
plt.ylabel('Discharge (m3/s)')
plt.xlabel('Timestep (Daily)')
plt.legend()
plt.show()
plt.savefig('Discharge in Rhine Basin.png', dpi=300)
plt.close()

# %%
# Plotting

plt.plot(timestamps_100r, discharge1_85r, label='Less rain by 15%', color='#A95681')
plt.plot(timestamps_100r, discharge1_100r, label='unmodified rain', color='#5681A9')
plt.plot(timestamps_100r, discharge1_60r, label='Less rain by 40%', color='#81A956')
plt.title('Discharge in Rhine basin')
plt.ylabel('Discharge (m3/s)')
plt.xlabel('Timestep (Daily)')
plt.legend()
plt.savefig('Discharge in Rhine Basin rain.png', dpi=300)
plt.close()

# %%
plt.plot(timestamps_100r, discharge1_116t, label='warmer by 2 deg c', color='#A95681')
plt.plot(timestamps_100r, discharge1_100r, label='unmodified temperature', color='#5681A9')
plt.plot(timestamps_100r, discharge1_140t, label='watmer by 5 deg c', color='#81A956')
plt.title('Discharge in Rhine basin')
plt.ylabel('Discharge (m3/s)')
plt.xlabel('Timestep (Daily)')
plt.legend()
plt.show()
plt.savefig('Discharge in Rhine Basin.png', dpi=300)
plt.close()

# %%
plt.plot(timestamps_100r, discharge1_116t, label='warmer by 2 deg c', color='#A95681')
plt.plot(timestamps_100r, discharge1_100r, label='unmodified temperature', color='#5681A9')
plt.plot(timestamps_100r, discharge1_140t, label='watmer by 5 deg c', color='#81A956')
plt.title('Discharge in Rhine basin')
plt.ylabel('Discharge (m3/s)')
plt.xlabel('Timestep (Daily)')
plt.legend()
plt.savefig('Discharge in Rhine Basin temp.png', dpi=300)
plt.close()

# %% [markdown]
# # Averages calculations

# %%
average_100r = np.mean(discharge1_100r)
average_85r = np.mean(discharge1_85r)
average_60r = np.mean(discharge1_60r)
average_116t = np.mean(discharge1_116t)
average_140t = np.mean(discharge1_140t)

# %%
print("average discharge for unmodified rain and temp= ", average_100r)
print("average discharge for less 15% rain rain= ", average_85r)
print("average discharge for less 40% rain= ", average_60r)
print("average discharge for warmer temperature by 2 deg c= ", average_116t)
print("average discharge for warmer temperature by 5 deg c= ", average_140t)
# Out:
# average discharge for unmodified rain and temp=  2334.7366590038314
# average discharge for less 15% rain rain=  1667.1808215654075
# average discharge for less 40% rain=  728.9518598795839
# average discharge for warmer temperature by 2 deg c=  2343.7855265462504
# average discharge for warmer temperature by 5 deg c=  2355.235159277504

# %% [markdown]
# # Part 2 - snow

# %%
file_path = 'D:/CWatM/Tutorials/11_SensitivityAnalysis/run_0snow/discharge_daily.tss'

# Define lists to store timestamps and values
timestamps_0s = []
discharge1_0s = []  
discharge2_0s = [] 

# Open the file and read its contents
with open(file_path, 'r') as file:
    # Skip first lines until we reach the data
    for line in file:
        if line.strip().isdigit():
            break
    
    # Process the remaining lines containing data
    for line in file:
        # Split the line by whitespace
        parts = line.split()
        if len(parts) == 3:  # Assuming timestamp and two values
            timestamp = int(parts[0])
            value1 = float(parts[1])
            value2 = float(parts[2])
            
            # Append data to lists
            timestamps_0s.append(timestamp)
            discharge1_0s.append(value1)
            discharge2_0s.append(value2)

# # # Print the extracted data
# for i in range(len(timestamps)):
#     print(f"Timestamp: {timestamps[i]}, Value1: {discharge1[i]}, Value2: {discharge2[i]}")

# %%
file_path = 'D:/CWatM/Tutorials/11_SensitivityAnalysis/run_015snow/discharge_daily.tss'

# Define lists to store timestamps and values
timestamps_015s = []
discharge1_015s = []  
discharge2_015s = [] 

# Open the file and read its contents
with open(file_path, 'r') as file:
    # Skip first lines until we reach the data
    for line in file:
        if line.strip().isdigit():
            break
    
    # Process the remaining lines containing data
    for line in file:
        # Split the line by whitespace
        parts = line.split()
        if len(parts) == 3:  # Assuming timestamp and two values
            timestamp = int(parts[0])
            value1 = float(parts[1])
            value2 = float(parts[2])
            
            # Append data to lists
            timestamps_015s.append(timestamp)
            discharge1_015s.append(value1)
            discharge2_015s.append(value2)

# # # Print the extracted data
# for i in range(len(timestamps)):
#     print(f"Timestamp: {timestamps[i]}, Value1: {discharge1[i]}, Value2: {discharge2[i]}")

# %%
# Normalize timestamp to start from 0
## 0 means 1/1/2000

first_timestamp = timestamps_0s[0]

for i in range(len(timestamps_0s)):
    timestamps_0s[i] = timestamps_0s[i] - first_timestamp

# %%
# Normalize timestamp to start from 0
## 0 means 1/1/2000

first_timestamp = timestamps_015s[0]

for i in range(len(timestamps_015s)):
    timestamps_015s[i] = timestamps_015s[i] - first_timestamp

# %%
# Plotting

plt.plot(timestamps_0s, discharge1_0s, label='Temperature of rain/snow = 0 deg c', color='#A95681')
plt.plot(timestamps_0s, discharge1_100r, label='Temperature of rain/snow = 1 deg c', color='#5681A9')
plt.plot(timestamps_0s, discharge1_015s, label='Temperature of rain/snow = 1.5 deg c', color='#81A956')
plt.title('Discharge in Rhine basin')
plt.ylabel('Discharge (m3/s)')
plt.xlabel('Timestep (Daily)')
plt.legend()
plt.show()
plt.savefig('Discharge in Rhine Basin.png', dpi=300)
plt.close()

# %%
# Plotting

plt.plot(timestamps_0s, discharge1_0s, label='Temperature of rain/snow = 0 deg c', color='#A95681')
plt.plot(timestamps_0s, discharge1_100r, label='Temperature of rain/snow = 1 deg c', color='#5681A9')
plt.plot(timestamps_0s, discharge1_015s, label='Temperature of rain/snow = 1.5 deg c', color='#81A956')
plt.title('Discharge in Rhine basin')
plt.ylabel('Discharge (m3/s)')
plt.xlabel('Timestep (Daily)')
plt.legend()
plt.savefig('Discharge in Rhine Basin snow.png', dpi=300)
plt.close()

# %%
average_100r = np.mean(discharge1_100r)
average_0s = np.mean(discharge1_0s)
average_015s = np.mean(discharge1_015s)

# %%
print("average discharge for unmodified tempsnow (1 deg c)= ", average_100r)
print("average discharge for 0 temp snow= ", average_0s)
print("average discharge for 1.5 temp snow= ", average_015s)
# Out:
# average discharge for unmodified tempsnow (1 deg c)=  2334.7366590038314
# average discharge for 0 temp snow=  2341.9108035030104
# average discharge for 1.5 temp snow=  2330.590486590038
